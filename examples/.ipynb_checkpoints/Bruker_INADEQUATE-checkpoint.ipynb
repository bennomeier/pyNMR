# %% [markdown]
# # DNP Spectrum Analysis

# %%
from pyNMR.viewer import gui as mygui

import pyNMR.model.parser.topSpin as T
import pyNMR.model.processor as P
import pyNMR.model.operations as O

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
exp = "dnp_210316_1_solids/1/"
path = "/opt/nmrdata/user/" + exp 
localPath = "./microwaveFrequencySweeps/rawData/"

server = "ibg-4-charlie.ibg.kit.edu"
user = "nmr"
password = ""

data = T.TopSpinSSH(path, exp, localPath, server, user, password)

# %%
data = T.TopSpin("./data/bruker/dnp_210316_1_solids/1/")


Processor = P.Processor([O.LeftShift(21),
                         O.LineBroadening(0.2),
                         O.FourierTransform(),
                       O.Phase0D(170)])
Processor.runStack(data)

OP = O.GetPartialSpectrum(15, -200e3, 200e3)
spec = OP.run(data)
# Out:
# RUN STACK
# Left Shift
# Exponential Linebroadening
# Fourier Transform
# Phase Zero Order

# %%
OP = O.GetJoinedPartialSpectra(-200e3, 200e3, returnX=True)
x, spec = OP.run(data)

import matplotlib.pyplot as plt
import numpy as np
plt.plot(x, spec)
plt.grid()

# %%
OP = O.GetAllIntegrals(-200e3, 200e3)
OP2 = O.GetAllPhases(-200e3, 200e3, unwrap = True)
myList = OP.run(data)
myPhaseList = OP2.run(data)

# %%
xAxis = np.array([188.6 + 0.005*i for i in range(53)]) - 180

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(xAxis, myList)
plt.xlabel("Frequency (GHz) - 180")
plt.grid()
plt.subplot(1,2,2)
plt.ylabel("Phase (Deg)")
plt.xlabel("Frequency (GHz) - 180")
plt.grid()
plt.plot(xAxis,myPhaseList)

# %%
print(data.title)
# Out:
# ['DNP Frequency Sweep', 'freq 188600 MHz', 'buildup time per step: 30s', 'step size 5 MHz, 53 steps', '13C NMR']
